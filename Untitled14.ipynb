# %% [markdown]
# TASK 3 MAIN FLOW

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

# %%
data=pd.read_csv('householdtask3.csv')
data
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %%
data.head(10)
# Out:
#    year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0  2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1  2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2  2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3  2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4  2008   312240   217657  141318      69.7         45.3      20.0  31.5
# 5  2008   312336   229014  147658      73.3         47.3      20.0  35.3
# 6  2008   311574   253235  152835      81.3         49.1      20.0  39.3
# 7  2008   312761   194358   49448      62.1         15.8      20.0  38.7
# 8  2008   311973   206342   86390      66.1         27.7      20.0  36.1
# 9  2008   311840   194361  108065      62.3         34.7      20.0  33.0
#
#    size  income  expenditure  eqv_income  eqv_exp
# 0   2.7   46704        42394       26869    25132
# 1   2.6   23404        25270       14258    15824
# ...

# %%
#scatter plot
colors = np.random.rand(70)
plt.scatter(data['year'],data['own'],c=colors,alpha=0.9,cmap='viridis')
plt.colorbar()
plt.title('scatter plot')
plt.xlabel('year')
plt.ylabel('own')
plt.show()

# %%
#line plot
plt.plot(data['year'],data['income'],color='b',linestyle=':',marker='o')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.title('lineplot')
plt.xlabel('year')
plt.ylabel('income')
plt.show()

# %%
#bar plot
plt.bar(data['year'],data['eqv_income'],color='r',width=1.5,align='center',edgecolor='y')
plt.title('BarPlot')
plt.xlabel('year')
plt.ylabel('eqv_income')
plt.show()

# %%
# HORIXONTAL bar plot
plt.barh(data['year'],data['eqv_income'])
plt.title('BarPlot')
plt.xlabel('year')
plt.ylabel('eqv_income')
plt.show()

# %%
#stacked bar plot
plt.bar(data['year'],data['income'],color='green',width=1.5)
plt.bar(data['year'],data['eqv_income'],color='blue',width=1.5)
plt.title('BarPlot')
plt.xlabel('year')
plt.ylabel('eqv_income and income')
plt.show()

# %%
plt.hist(data['income'],color='yellow',edgecolor='r')
plt.hist(data['eqv_income'],color='m',edgecolor='g')
plt.title('HISTOGRAM')
plt.xlabel('year')
plt.ylabel('own')
plt.show()
